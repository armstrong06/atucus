# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm 
from sklearn.isotonic import IsotonicRegression

# %%
ls ../uuss_data/p_resampled
# Out:
# uuss_NGB_4s_1dup.h5  uuss_test_fewerhist_4s_1dup.h5  uuss_train.csv
# uuss_NGB.csv         uuss_test_fewerhist.csv         uuss_validation_4s_1dup.h5
# uuss_test.csv        uuss_train_4s_1dup.h5           uuss_validation.csv

# %%
def load_model_results(file_name):
    file = np.load(file_name)
    predictions = file["predictions"]
    targets = file["targets"][:, 0]
    pred_mean = file["prediction_mean"]
    pred_std = file["prediction_std"]
    resids = targets - pred_mean

    return predictions, pred_mean, pred_std, targets, resids

def make_prediction_df(means, stds, targets, residuals):
    # Combine into a dataframe
    df_data = {"y_pred":means, "std":stds, "y_act":targets, "residual":residuals}
    df = pd.DataFrame(data=df_data)
    df.head()

    return df

# %% [markdown]
# # Accurate Uncertainties for Deep Learning Using Calibrated Regression
# Recalibration dataset $D = \{ (F_t(y_t) , \hat{P}(F_t(y_t))) \}_{t=1}^T$
# 1. Compute $F_t$ = CDF[$N(\mu_t, \sigma^2_t)]$ for t $\in$ [1, T]
# 2. Evalute $F_t(y_t)$ for t $\in$ [1, T]
# 3. compute $\hat{P}(p)=\frac{| \{y_t | F_t(y_t) \leq p, t=1...,T \}|}{T}$, where $p=F_t(y_t)$ for t $\in$ [1, T]
#
# Fit Isotonic Regression model R to D
#
# - Fitting regression model to D' = $\{( \hat{P}(F_t(y_t)), F_t(y_t)) \}_{t=1}^T$ seems easier for adjusting the "standard deviation" to be calibrated.
# - When using D, will need to compute the CDF of the Gaussian with predicted $\mu$ and $\sigma$, transform with R, and then invert for $x_{lb}$ and $x_{ub}$. Since the CDF has been transformed, norm.ppf can no longer be used to invert.
# - When using D', can compute the ppf of the gaussian with predicted $\mu$ and $\sigma$ and evaluate it at R(lb) and R(ub).
# - I show below that $x_{lb}$ and $x_{ub}$ computed using the D' method intersect with the transformed CDF computed using D at 0.16 and 0.84.

# %% [markdown]
# ## Fit Predicted vs Empirical Curve $D = \{ (F_t(y_t) , \hat{P}(F_t(y_t))) \}_{t=1}^T$ with Isotonic Regression

# %%
# Do steps 1 & 2
def eval_cdf(df):
    df["cdf"] = df.apply(lambda x: norm.cdf(x["y_act"], x["y_pred"], x["std"]), axis=1)
    print(df.head())

# %%
# Do step 3
def plot_empirical_cdf(df, swap_xy=False):
    fig = plt.figure()
    plt.plot(np.arange(0, 1.01, 0.1), np.arange(0, 1.01, 0.1), color="gray", linestyle="--", label="Perfect Calibration")
    if not swap_xy:
        plt.scatter(df.cdf.values, df.p_hat.values, alpha=0.1)
        plt.ylabel("Empirical Cumulative Distribution")
        plt.xlabel("Predicted Cumulative Distribution")
    else:
        plt.scatter(df.p_hat.values, df.cdf.values, alpha=0.1)
        plt.xlabel("Empirical Cumulative Distribution")
        plt.ylabel("Predicted Cumulative Distribution")
    plt.title("Estimating Cumulative Density of Forecast")
    plt.legend();
    plt.show()
    
def compute_empirical_cdf(df, swap_xy=False):
    p_hat = []
    T = len(df)
    for index, row in df.iterrows():
        p = row["cdf"]
        p_hat.append((df["cdf"] <= p).sum()/T)
    df["p_hat"] = p_hat

    #plot_empirical_cdf(df, swap_xy)

# %%
def check_nondecreasing(df):
    assert ~np.any(np.diff(df.sort_values("cdf")["p_hat"].values) < 0), "CDF vs P_Hat is not non-decreasing"
    assert ~np.any(np.diff(df.sort_values("p_hat")["cdf"].values) < 0), "P_Hat vs CDF is not non-decreasing"

# %%
def plot_calibration_curves(df, regressors, title, swap_xy=False):
    
    plt.plot(np.arange(0, 1.05, 0.05), np.arange(0, 1.05, 0.05), color="gray", linestyle="--")
    colors = plt.cm.viridis(np.linspace(0,1,len(regressors)))
    for i in range(len(regressors)):
        regressor = regressors[i]
        p_hat_cal = []
        p_hat_uncal = []
        T = len(df)
        for p in np.arange(0, 1.05, 0.05):
            if swap_xy:
                p_hat_cal.append((df.cdf <= regressor.predict([p])[0]).sum()/T)
            else:
                p_hat_cal.append((regressor.predict(df.cdf) <= p).sum()/T)

            p_hat_uncal.append((df["cdf"] <= p).sum()/T)

        #plt.plot(np.arange(0, 1.05, 0.05), p_hat_cal, marker="o", label="calibrated")
        plt.plot(np.arange(0, 1.05, 0.05), p_hat_uncal, color=colors[i], linewidth=0.5)
#    plt.legend()
    plt.title(title)

# %% [markdown]
# ## Fit Empirical vs Predicted Curve $D=\{( \hat{P}(F_t(y_t)), F_t(y_t)) \}_{t=1}^T$ with Isotonic Regression

# %%
ls
# Out:
# calibrated_regression_p-Copy1.ipynb
# calibrated_regression_p_individual.ipynb
# ensemble_results_NGB.ipynb
# ensemble_results_test.ipynb
# eval_swag_picker.sh*
# figures/
# figures_NGB/
# out.eval_ensemble_NGB
# out.eval_ensemble_test_fh
# out.eval_ensemble_validation
# out.train_ensemble
# p_calibration_model.joblib
# seed1_128_0.0005_5e-3_0.0002_61_26_20/
# seed2_128_0.0005_5e-3_0.0002_61_26_20/
# seed3_128_0.0005_5e-3_0.0002_61_26_20/
# train_swag_picker.sh*

# %%
ls ../p_tuning/SWAG_tune_lr_ft24/128_0.0005_5e-3_0.0002_84_24_20
# Out:
# checkpoint-24.pt  checkpoint-56.pt   swag-26.pt  swag-58.pt
# checkpoint-25.pt  checkpoint-57.pt   swag-27.pt  swag-59.pt
# checkpoint-26.pt  checkpoint-58.pt   swag-28.pt  swag-60.pt
# checkpoint-27.pt  checkpoint-59.pt   swag-29.pt  swag-61.pt
# checkpoint-28.pt  checkpoint-60.pt   swag-30.pt  swag-62.pt
# checkpoint-29.pt  checkpoint-61.pt   swag-31.pt  swag-63.pt
# checkpoint-30.pt  checkpoint-62.pt   swag-32.pt  swag-64.pt
# checkpoint-31.pt  checkpoint-63.pt   swag-33.pt  swag-65.pt
# checkpoint-32.pt  checkpoint-64.pt   swag-34.pt  swag-66.pt
# checkpoint-33.pt  checkpoint-65.pt   swag-35.pt  swag-67.pt
# checkpoint-34.pt  checkpoint-66.pt   swag-36.pt  swag-68.pt
# checkpoint-35.pt  checkpoint-67.pt   swag-37.pt  swag-69.pt
# checkpoint-36.pt  checkpoint-68.pt   swag-38.pt  swag-70.pt
# checkpoint-37.pt  checkpoint-69.pt   swag-39.pt  swag-71.pt
# checkpoint-38.pt  checkpoint-70.pt   swag-40.pt  swag-72.pt
# checkpoint-39.pt  checkpoint-71.pt   swag-41.pt  swag-73.pt
# checkpoint-40.pt  checkpoint-72.pt   swag-42.pt  swag-74.pt
# checkpoint-41.pt  checkpoint-73.pt   swag-43.pt  swag-75.pt
# checkpoint-42.pt  checkpoint-74.pt   swag-44.pt  swag-76.pt
# checkpoint-43.pt  checkpoint-75.pt   swag-45.pt  swag-77.pt
# checkpoint-44.pt  checkpoint-76.pt   swag-46.pt  swag-78.pt
# checkpoint-45.pt  checkpoint-77.pt   swag-47.pt  swag-79.pt
# checkpoint-46.pt  checkpoint-78.pt   swag-48.pt  swag-80.pt
# checkpoint-47.pt  checkpoint-79.pt   swag-49.pt  swag-81.pt
# checkpoint-48.pt  checkpoint-80.pt   swag-50.pt  swag-82.pt
# checkpoint-49.pt  checkpoint-81.pt   swag-51.pt  swag-83.pt
# checkpoint-50.pt  checkpoint-82.pt   swag-52.pt  swag-84.pt
# checkpoint-51.pt  checkpoint-83.pt   swag-53.pt  train_metrics.csv
# checkpoint-52.pt  checkpoint-84.pt   swag-54.pt  val_results_100/
# checkpoint-53.pt  command.sh         swag-55.pt  val_results_30/
# checkpoint-54.pt  sgd_ens_preds.npz  swag-56.pt
# checkpoint-55.pt  swag-25.pt         swag-57.pt

# %%
seeds = [1] #, 2, 3]
all_p_hat_uncal = []
for seed in seeds:
    p_hat_uncal = []
    cdf_vals = []
    for i in range(62, 80):
        val_file = f"seed{seed}_128_0.0005_5e-3_0.0002_61_26_20/eval_more/swag_validation_uncertainty_{i}.npz"
        val_preds, val_pred_mean, val_pred_std, val_targets, val_resids = load_model_results(val_file)
        val_df = make_prediction_df(val_pred_mean, val_pred_std, val_targets, val_resids)
        eval_cdf(val_df)
        T = len(val_df)
        df_val_p_hat = []
        for p in np.arange(0, 1.05, 0.05):
             df_val_p_hat.append((val_df["cdf"] <= p).sum()/T)        
        p_hat_uncal.append(df_val_p_hat)
    all_p_hat_uncal.append(p_hat_uncal)
#plot_calibration_curve(val_df, iso_reg_inv, r"Validation Calibration Curve - fit$(\hat{P}, F_t)$", swap_xy=True)
# Out:
#      y_pred       std  y_act  residual       cdf
# 0  0.214092  0.174443   0.32  0.105908  0.728114
# 1  0.155489  0.134933   0.20  0.044511  0.629253
# 2  0.364965  0.277998   0.43  0.065035  0.592485
# 3  0.375508  0.295237   0.45  0.074492  0.599600
# 4  0.222843  0.162180   0.18 -0.042843  0.395824
#      y_pred       std  y_act  residual       cdf
# 0  0.193600  0.171538   0.32  0.126400  0.769398
# 1  0.146109  0.141203   0.20  0.053891  0.648641
# 2  0.377097  0.284153   0.43  0.052903  0.573848
# 3  0.341650  0.279548   0.45  0.108350  0.650840
# 4  0.201953  0.141995   0.18 -0.021953  0.438567
#      y_pred       std  y_act  residual       cdf
# 0  0.175132  0.173124   0.32  0.144868  0.798644
# 1  0.142033  0.122247   0.20  0.057967  0.682315
# 2  0.361537  0.277267   0.43  0.068463  0.597515
# 3  0.285333  0.248024   0.45  0.164667  0.746627
# 4  0.179779  0.139926   0.18  0.000221  0.500630
#      y_pred       std  y_act  residual       cdf
# 0  0.195468  0.145378   0.32  0.124532  0.804169
# 1  0.176628  0.129838   0.20  0.023372  0.571427
# 2  0.389803  0.236699   0.43  0.040197  0.567426
# 3  0.346705  0.223630   0.45  0.103295  0.677923
# 4  0.200908  0.134220   0.18 -0.020908  0.438106
#      y_pred       std  y_act  residual       cdf
# 0  0.186082  0.150934   0.32  0.133918  0.812530
# 1  0.116479  0.152753   0.20  0.083521  0.707731
# 2  0.342573  0.262516   0.43  0.087427  0.630446
# 3  0.329000  0.248994   0.45  0.121000  0.686501
# 4  0.173097  0.141455   0.18  0.006903  0.519460
#      y_pred       std  y_act  residual       cdf
# 0  0.174779  0.123396   0.32  0.145221  0.880376
# 1  0.102988  0.115879   0.20  0.097012  0.798755
# 2  0.298992  0.226321   0.43  0.131008  0.718658
# 3  0.271038  0.214004   0.45  0.178962  0.798494
# 4  0.167876  0.120798   0.18  0.012124  0.539973
#      y_pred       std  y_act  residual       cdf
# 0  0.122962  0.152357   0.32  0.197038  0.902040
# 1  0.103729  0.076184   0.20  0.096271  0.896825
# 2  0.256506  0.197379   0.43  0.173494  0.810297
# 3  0.188689  0.181808   0.45  0.261311  0.924682
# 4  0.127641  0.100123   0.18  0.052359  0.699496
#      y_pred       std  y_act  residual       cdf
# 0  0.109033  0.131940   0.32  0.210967  0.945086
# 1  0.085278  0.108836   0.20  0.114722  0.854078
# 2  0.211585  0.209844   0.43  0.218415  0.851026
# 3  0.176057  0.203864   0.45  0.273943  0.910486
# 4  0.090679  0.106567   0.18  0.089321  0.799032
#      y_pred       std  y_act  residual       cdf
# 0  0.124880  0.111108   0.32  0.195120  0.960466
# 1  0.065596  0.076173   0.20  0.134404  0.961172
# 2  0.168644  0.200927   0.43  0.261356  0.903328
# 3  0.138716  0.183146   0.45  0.311284  0.955402
# 4  0.085458  0.117648   0.18  0.094542  0.789187
#      y_pred       std  y_act  residual       cdf
# 0  0.140214  0.101379   0.32  0.179786  0.961918
# 1  0.055161  0.078903   0.20  0.144839  0.966796
# 2  0.221821  0.203884   0.43  0.208179  0.846389
# 3  0.160089  0.186843   0.45  0.289911  0.939624
# 4  0.090350  0.107109   0.18  0.089650  0.798703
#      y_pred       std  y_act  residual       cdf
# 0  0.120358  0.166892   0.32  0.199642  0.884198
# 1  0.041488  0.082219   0.20  0.158513  0.973067
# 2  0.172645  0.192763   0.43  0.257355  0.909076
# 3  0.107880  0.161677   0.45  0.342120  0.982830
# 4  0.081959  0.080048   0.18  0.098041  0.889671
#      y_pred       std  y_act  residual       cdf
# 0  0.095548  0.141718   0.32  0.224452  0.943379
# 1  0.027090  0.093037   0.20  0.172910  0.968452
# 2  0.193880  0.208172   0.43  0.236120  0.871655
# 3  0.121062  0.161229   0.45  0.328938  0.979335
# 4  0.094786  0.102020   0.18  0.085214  0.798216
#      y_pred       std  y_act  residual       cdf
# 0  0.137235  0.162787   0.32  0.182765  0.869223
# 1  0.042337  0.108100   0.20  0.157663  0.927648
# 2  0.212881  0.258991   0.43  0.217119  0.799076
# 3  0.119578  0.175951   0.45  0.330421  0.969804
# 4  0.089747  0.090241   0.18  0.090253  0.841377
#      y_pred       std  y_act  residual       cdf
# 0  0.108463  0.101157   0.32  0.211537  0.981744
# 1  0.039272  0.118698   0.20  0.160728  0.912146
# 2  0.216313  0.205512   0.43  0.213687  0.850779
# 3  0.138040  0.177064   0.45  0.311960  0.960953
# 4  0.079386  0.124520   0.18  0.100614  0.790458
#      y_pred       std  y_act  residual       cdf
# 0  0.103429  0.109547   0.32  0.216571  0.975977
# 1  0.076351  0.096411   0.20  0.123649  0.900170
# 2  0.194777  0.202316   0.43  0.235223  0.877515
# 3  0.090672  0.175926   0.45  0.359328  0.979449
# 4  0.093610  0.126622   0.18  0.086390  0.752464
#      y_pred       std  y_act  residual       cdf
# 0  0.082175  0.117597   0.32  0.237825  0.978431
# 1  0.030171  0.093827   0.20  0.169829  0.964854
# 2  0.228121  0.235263   0.43  0.201879  0.804581
# 3  0.111270  0.174911   0.45  0.338730  0.973602
# 4  0.096490  0.131065   0.18  0.083510  0.737990
#      y_pred       std  y_act  residual       cdf
# 0  0.064498  0.147051   0.32  0.255502  0.958851
# 1  0.021066  0.092238   0.20  0.178934  0.973805
# 2  0.164326  0.218287   0.43  0.265674  0.888214
# 3  0.093244  0.149653   0.45  0.356756  0.991435
# 4  0.077093  0.143565   0.18  0.102907  0.763251
#      y_pred       std  y_act  residual       cdf
# 0  0.094689  0.100848   0.32  0.225311  0.987264
# 1  0.047156  0.121674   0.20  0.152844  0.895473
# 2  0.270292  0.261948   0.43  0.159708  0.728967
# 3  0.136917  0.192496   0.45  0.313083  0.948072
# 4  0.118178  0.200685   0.18  0.061822  0.620979

# %%
def plot_uncalibrated_curves(all_p_hat_uncal, title):
    fig, ax = plt.subplots(2, 1, figsize=(10, 10), gridspec_kw={'height_ratios': [2, 1]})
    ax[0].plot(np.arange(0, 1.05, 0.05), np.arange(0, 1.05, 0.05), color="gray", linestyle="--")
    colors = plt.cm.viridis(np.linspace(0,1,len(all_p_hat_uncal)))
    for i in range(len(all_p_hat_uncal)):
        ax[0].plot(np.arange(0, 1.05, 0.05), all_p_hat_uncal[i], color=colors[i], linewidth=0.5)
#     ax[0].plot(np.arange(0, 1.05, 0.05), all_p_hat_uncal[30], color="red", linewidth=1.0)
#     ax[0].plot(np.arange(0, 1.05, 0.05), all_p_hat_uncal[40], color="red", linewidth=1.0)
        ax[0].plot(np.arange(0, 1.05, 0.05), all_p_hat_uncal[17], color="red", linewidth=1.0)

    ax[0].set_title(title)
    ax[0].set_xlabel("Predicted")
    ax[0].set_ylabel("Empirical")
    ax[1].imshow([colors])
    ax[1].set_xlabel("epochs")
    plt.yticks([])

# %%
plot_uncalibrated_curves(all_p_hat_uncal[0], title="seed 1")

# %%
file = f"seed1_128_0.0005_5e-3_0.0002_61_26_20/train_metrics.csv"
df = pd.read_csv(file)
plt.plot(range(len(df)), df.swa_va_rms)
file = f"seed1_128_0.0005_5e-3_0.0002_61_26_20/train_metrics_og.csv"
df = pd.read_csv(file)
plt.plot(range(len(df)), df.swa_va_rms)

# %%
df
# Out:
#     ep      lr   tr_loss    tr_rms   va_loss    va_rms  swa_va_loss  \
# 0   62  0.0002  0.041365  0.203383  0.020527  0.143274     0.012698
# 1   63  0.0002  0.018433  0.135768  0.017399  0.131904     0.022624
# 2   64  0.0002  0.016390  0.128022  0.016061  0.126734     0.034513
# 3   65  0.0002  0.015303  0.123706  0.015156  0.123109     0.046157
# 4   66  0.0002  0.014498  0.120408  0.014420  0.120083     0.055901
# 5   67  0.0002  0.013852  0.117695  0.013836  0.117628     0.062060
# 6   68  0.0002  0.013367  0.115614  0.013445  0.115954     0.066841
# 7   69  0.0002  0.012871  0.113453  0.013100  0.114455     0.070373
# 8   70  0.0002  0.012499  0.111797  0.012634  0.112402     0.072604
# 9   71  0.0002  0.012104  0.110020  0.012362  0.111184     0.073754
# 10  72  0.0002  0.011777  0.108522  0.011977  0.109440     0.074120
# 11  73  0.0002  0.011482  0.107153  0.011846  0.108841     0.073843
# 12  74  0.0002  0.011201  0.105833  0.011541  0.107428     0.073198
# 13  75  0.0002  0.010970  0.104738  0.011397  0.106759     0.072344
# 14  76  0.0002  0.010734  0.103606  0.011171  0.105694     0.071313
# 15  77  0.0002  0.010524  0.102586  0.011067  0.105200     0.070055
# 16  78  0.0002  0.010356  0.101767  0.010938  0.104585     0.068668
# 17  79  0.0002  0.010216  0.101076  0.010862  0.104221     0.067244
# 18  80  0.0002  0.010029  0.100144  0.010713  0.103503     0.065764
# 19  81  0.0002  0.009819  0.099091  0.010647  0.103185     0.064300
# 20  82  0.0002  0.009660  0.098286  0.010633  0.103117     0.062677
# 21  83  0.0002  0.009479  0.097361  0.010538  0.102655     0.061066
# 22  84  0.0002  0.009345  0.096667  0.010499  0.102463     0.059413
# 23  85  0.0002  0.009211  0.095975  0.010382  0.101893     0.057772
# 24  86  0.0002  0.009007  0.094904  0.010335  0.101660     0.056085
#
#     swa_va_rms       time  mem_usage
# 0     0.112686  25.019536   0.683647
# 1     0.150413  24.933348   0.684272
# 2     0.185778  24.410223   0.683647
# 3     0.214841  23.791097   0.684272
# 4     0.236433  25.029682   0.683921
# 5     0.249119  25.426759   0.683647
# 6     0.258536  24.406575   0.683921
# 7     0.265279  24.109113   0.683921
# 8     0.269451  23.977657   0.684272
# 9     0.271577  24.649311   0.683647
# 10    0.272249  24.962707   0.683921
# 11    0.271741  24.851313   0.683647
# 12    0.270551  24.737087   0.684547
# 13    0.268968  25.359525   0.684272
# 14    0.267044  24.719295   0.683647
# 15    0.264678  24.901397   0.683647
# 16    0.262046  24.611535   0.684272
# 17    0.259314  24.430870   0.683647
# 18    0.256444  25.186265   0.684272
# 19    0.253574  24.748273   0.683921
# 20    0.250353  24.663557   0.684272
# 21    0.247115  25.419132   0.683647
# 22    0.243749  25.678282   0.684272
# 23    0.240359  25.212479   0.683647
# 24    0.236822  25.111236   0.684547

# %%
plot_uncalibrated_curves(all_p_hat_uncal[1], title="seed 2")

# %%
plot_uncalibrated_curves(all_p_hat_uncal[2], title="seed 3")

# %%
# Pull out a few epochs from 0.0002 run
plt.figure(figsize=(10, 7))
plt.plot(np.arange(0, 1.05, 0.05), np.arange(0, 1.05, 0.05), color="gray", linestyle="--")
plt.plot(np.arange(0, 1.05, 0.05), all_p_hat_uncal[0][0], label="seed 1")
plt.plot(np.arange(0, 1.05, 0.05), all_p_hat_uncal[1][0], label="seed 2")
plt.plot(np.arange(0, 1.05, 0.05), all_p_hat_uncal[2][0], label="seed 3")
# plt.plot(np.arange(0, 1.05, 0.05), all_p_hat_uncal[1][45], label="45")
# plt.plot(np.arange(0, 1.05, 0.05), all_p_hat_uncal[1][50], label="50")
plt.legend()

# %%
plt.figure(figsize=(10, 7))
plt.plot(np.arange(0, 1.05, 0.05), np.arange(0, 1.05, 0.05), color="gray", linestyle="--")
plt.plot(np.arange(0, 1.05, 0.05), all_p_hat_uncal[0][58])
plt.plot(np.arange(0, 1.05, 0.05), all_p_hat_uncal[1][35])

# %% [markdown]
# Can get pretty similar results by going to ~35 epochs with 0.0002 or through ~60 iterations with 0.0001. This makes sense given that the learning rates aren't very far off. Double the learning rate, half the number of iterations to converage. Both have similar RMS/OF STD at 35 and 60 epochs, respectivley. Both pretty similarlly calibrated. Go with 0.0002 for 35 epochs.
