# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Fine-tune RMS (where these start) is 0.08495

# %%
learing_rates = ["0.00005", "0.0001", "0.0005", "0.001", "0.005", "0.01", "0.05", "0.1"]
for lr in learing_rates:
    dir_name = f"SWAG_tune_lr/128_0.001_5e-3_{lr}_48_13_20"
    df = pd.read_csv(f"{dir_name}/train_metrics.csv")
    plt.plot(range(len(df)), df.swa_va_rms, label=f"{lr}_swa")
plt.legend()

# %%
learing_rates = ["0.00005", "0.0001", "0.0002", "0.0003", "0.0004", "0.0005", "0.001", "0.005"]
for lr in learing_rates:
    dir_name = f"SWAG_tune_lr/128_0.001_5e-3_{lr}_48_13_20"
    df = pd.read_csv(f"{dir_name}/train_metrics.csv")
    plt.plot(range(len(df)), df.swa_va_rms, label=f"{lr}_swa")
plt.legend()

# %%
learing_rates = ["0.0001", "0.0002"] #, "0.0003"]
for lr in learing_rates:
    dir_name = f"SWAG_tune_lr/128_0.001_5e-3_{lr}_48_13_20"
    df = pd.read_csv(f"{dir_name}/train_metrics.csv")
    print(np.min(df.swa_va_rms), np.argmin(df.swa_va_rms))
    plt.plot(range(len(df)), df.swa_va_rms, label=f"{lr}_swa")
    plt.plot(range(len(df)), df.va_rms, label=f"{lr}_swa", marker="x")

plt.legend()
# Out:
# 0.08356873558252946 32
# 0.08356231677720889 17

# %%
learing_rates = ["0.0001", "0.0002"]
for lr in learing_rates:
    dir_name = f"SWAG_tune_lr_ft24/128_0.0005_5e-3_{lr}_59_24_20"
    df = pd.read_csv(f"{dir_name}/train_metrics.csv")
    print(np.min(df.swa_va_rms), np.argmin(df.swa_va_rms))
    plt.plot(range(len(df)), df.swa_va_rms, label=f"{lr}_swa")
    plt.plot(range(len(df)), df.va_rms, label=f"{lr}_swa", marker="x")

plt.legend()
# Out:
# 0.0836281787856242 31
# 0.08365150755133709 16

# %%
learing_rates = ["0.0001", "0.0002"]
for lr in learing_rates:
    dir_name = f"SWAG_tune_lr_ft24/128_0.0005_5e-3_{lr}_84_24_20"
    df = pd.read_csv(f"{dir_name}/train_metrics.csv")
    print(np.min(df.swa_va_rms), np.argmin(df.swa_va_rms))
    plt.plot(range(len(df)), df.swa_va_rms, label=f"{lr}_swa")
    plt.plot(range(len(df)), df.va_rms, label=f"{lr}_swa", marker="x")

plt.legend()
# Out:
# 0.08362305754030103 31
# 0.08364773250003914 16

# %% [markdown]
# # Go with 0.0002
# Not perfect, but not to bad?

# %%
learing_rates = ["0.0001", "0.0002"]
for lr in learing_rates:
    ens_rms = []
    for i in range(25, 85):
        file_name = f"SWAG_tune_lr_ft24/128_0.0005_5e-3_{lr}_84_24_20/val_results_30/val_eval_swag-{i}_residual_summary_30.csv"
        df = pd.read_csv(file_name)
        ens_rms.append(df.ens_rms.iloc[29])
    plt.plot(range(len(ens_rms)), ens_rms, label=f"{lr}_swa")
        #plt.plot(range(len(df)), df.va_rms, label=f"{k}")
plt.legend()
plt.xlabel("Iterations")
plt.ylabel("RMS of 30 samples")
# Out:
# Text(0, 0.5, 'RMS of 30 samples')

# %%
learing_rates = ["0.0001", "0.0002"]
for lr in learing_rates:
    ens_of_std = []
    for i in range(25, 85):
        file_name = f"SWAG_tune_lr_ft24/128_0.0005_5e-3_{lr}_84_24_20/val_results_30/val_eval_swag-{i}_residual_summary_30.csv"
        df = pd.read_csv(file_name)
        ens_of_std.append(df.ens_of_std.iloc[29])
    plt.plot(range(len(ens_of_std)), ens_of_std, label=f"{lr}_swa")
        #plt.plot(range(len(df)), df.va_rms, label=f"{k}")
plt.legend()
plt.xlabel("Iterations")
plt.ylabel("RMS of 30 samples")
# Out:
# Text(0, 0.5, 'RMS of 30 samples')

# %%
file_name = np.load(f"SWAG_tune_lr_ft24/128_0.0005_5e-3_0.0001_84_24_20/val_results_30/val_eval_swag-74.npz")
residuals = (file_name["targets"]  - np.expand_dims(file_name["prediction_mean"], 1))
plt.hist(residuals, bins=np.arange(-0.25, 0.26, 0.01));

plt.figure()
file_name = np.load(f"SWAG_tune_lr_ft24/128_0.0005_5e-3_0.0002_84_24_20/val_results_30/val_eval_swag-59.npz")
residuals = (file_name["targets"]  - np.expand_dims(file_name["prediction_mean"], 1))
plt.hist(residuals, bins=np.arange(-0.25, 0.26, 0.01), alpha=0.5);

# %%
file_name = np.load(f"SWAG_tune_lr_ft24/128_0.0005_5e-3_0.0001_84_24_20/val_results_30/val_eval_swag-59.npz")
residuals = (file_name["targets"]  - np.expand_dims(file_name["prediction_mean"], 1))
plt.hist(residuals, bins=np.arange(-0.25, 0.26, 0.01));

file_name = np.load(f"SWAG_tune_lr_ft24/128_0.0005_5e-3_0.0001_84_24_20/val_results_30/val_eval_swag-26.npz")
residuals = (file_name["targets"]  - np.expand_dims(file_name["prediction_mean"], 1))
plt.hist(residuals, bins=np.arange(-0.25, 0.26, 0.01), alpha=0.5);

# %%
file_name = np.load(f"SWAG_tune_lr_ft24/128_0.0005_5e-3_0.0002_84_24_20/val_results_30/val_eval_swag-59.npz")
residuals = (file_name["targets"]  - np.expand_dims(file_name["prediction_mean"], 1))
plt.hist(residuals, bins=np.arange(-0.25, 0.26, 0.01));

file_name = np.load(f"SWAG_tune_lr_ft24/128_0.0005_5e-3_0.0002_84_24_20/val_results_30/val_eval_swag-27.npz")
residuals = (file_name["targets"]  - np.expand_dims(file_name["prediction_mean"], 1))
plt.hist(residuals, bins=np.arange(-0.25, 0.26, 0.01), alpha=0.5);

# %%
file_name = f"SWAG_tune_lr_ft24/128_0.0005_5e-3_0.0002_84_24_20/val_results_100/val_eval_swag-59_residual_summary_100.csv"
df = pd.read_csv(file_name)
df
# Out:
#     i_residual_mean  i_residual_std  i_of_mean  i_of_std     i_rms  \
# 0          0.002221        0.095587   0.004182  0.071421  0.095613
# 1          0.001960        0.094317   0.006658  0.063503  0.094337
# 2          0.003063        0.091978   0.006171  0.061187  0.092029
# 3          0.003235        0.086439   0.006545  0.051137  0.086499
# 4          0.000500        0.087678   0.002780  0.050248  0.087680
# ..              ...             ...        ...       ...       ...
# 95         0.000698        0.091027   0.005078  0.059357  0.091029
# 96         0.001529        0.095450   0.004710  0.061818  0.095463
# 97         0.003656        0.091771   0.005754  0.066796  0.091844
# 98         0.000412        0.113592   0.001796  0.105111  0.113593
# 99         0.000982        0.087692   0.003891  0.050617  0.087697
#
#     ens_residual_mean  ens_residual_std  ens_of_mean  ens_of_std   ens_rms
# 0            0.002221          0.095587     0.004182    0.071421  0.095613
# ...

# %%
file_name = f"SWAG_tune_lr_ft24/128_0.0005_5e-3_0.0002_84_24_20/val_results_100/val_eval_swag-59_residual_summary_100.csv"
df = pd.read_csv(file_name)
plt.plot(np.arange(len(df))+1, df.ens_of_std, label=f"35 epochs")
plt.legend()
plt.xlabel("Samples")
plt.ylabel("OF STD of N samples")
plt.xticks(np.arange(0, 110, 10))
plt.grid(True)
plt.ylim([0.04, 0.072])
# Out:
# (0.04, 0.072)

# %%
file_name = f"SWAG_tune_lr_ft24/128_0.0005_5e-3_0.0002_84_24_20/val_results_100/val_eval_swag-59_residual_summary_100.csv"
df = pd.read_csv(file_name)
plt.plot(np.arange(len(df))+1, df.ens_rms, label=f"35 epochs")
plt.legend()
plt.xlabel("Samples")
plt.ylabel("Ensemble RMS of N samples")
plt.xticks(np.arange(0, 110, 10))
plt.grid(True)
plt.ylim([0.084, 0.096])
# Out:
# (0.084, 0.096)

# %%
# Go with 25 samples

# %% [markdown]
# # Old stuff for comparison

# %%
learing_rates = ["0.0001", "0.0003", "0.0005", "0.0007", "0.001", "0.003", "0.005"]
for lr in learing_rates:
    dir_name = f"SWAG_ft_set/128_0.005_3e-4_{lr}_45_0"
    df = pd.read_csv(f"{dir_name}/train_metrics.csv")
    plt.plot(range(len(df)), df.va_rms, label=f"{lr}")
plt.legend()

# %%
learing_rates = ["0.0001", "0.0003", "0.0005", "0.0007", "0.001"]
for lr in learing_rates:
    dir_name = f"SWAG_ft_set/128_0.005_3e-4_{lr}_45_0"
    df = pd.read_csv(f"{dir_name}/train_metrics.csv")
    plt.plot(range(len(df)), df.swa_va_rms, label=f"{lr}_swa")
plt.legend()

# %%
0.0850-0.0825
# Out:
# 0.0025000000000000022

# %%
learing_rates = ["0.0001", "0.0003", "0.0005", "0.0007", "0.001"]
for lr in learing_rates:
    dir_name = f"SWAG_ft_set/128_0.005_3e-4_{lr}_45_0"
    df = pd.read_csv(f"{dir_name}/train_metrics.csv")
    plt.plot(range(len(df)), df.va_rms, label=f"{lr}")
plt.legend()

# %%
learing_rates = ["0.0001"]
for lr in learing_rates:
    dir_name = f"SWAG_ft_set/128_0.005_3e-4_{lr}_45_0"
    df = pd.read_csv(f"{dir_name}/train_metrics.csv")
    plt.plot(range(len(df)), df.swa_va_rms, label=f"{lr}_swa")
    plt.plot(range(len(df)), df.va_rms, label=f"{lr}")

plt.legend()

# %% [markdown]
# # More epochs, different K - used different fine-tuned models

# %%
K=[20, 60]
for k in K:
    dir_name = f"SWAG_tune_K/128_0.005_3e-4_0.0001_70_10_{k}"
    df = pd.read_csv(f"{dir_name}/train_metrics.csv")
    plt.plot(range(len(df)), df.swa_va_rms, label=f"{k}_swa")
    #plt.plot(range(len(df)), df.va_rms, label=f"{k}")
plt.legend()

# %%
K=[20, 60]
for k in K:
    dir_name = f"SWAG_tune_K/128_0.005_3e-4_0.0001_70_10_{k}"
    df = pd.read_csv(f"{dir_name}/train_metrics.csv")
    #plt.plot(range(len(df)), df.va_rms, label=f"{k}")
    plt.plot(range(11), df.va_rms[0:11], label=f"{k}")
plt.legend()

# %% [markdown]
# # More epochs, different K - used same fine-tuned model

# %%
K=[20, 60]
for k in K:
    dir_name = f"SWAG_tune_K/128_0.005_3e-4_0.0001_70_0_{k}"
    df = pd.read_csv(f"{dir_name}/train_metrics.csv")
    plt.plot(range(len(df)), df.swa_va_rms, label=f"{k}_swa")
    #plt.plot(range(len(df)), df.va_rms, label=f"{k}")
plt.legend()

# %%
import numpy as np

# %%
K=[20, 60]
for k in K:
    ens_rms = []
    for i in range(11, 71):
        file_name = f"SWAG_tune_K/128_0.005_3e-4_0.0001_70_0_{k}/val_results/val_eval_swag-{i}_residual_summary_30.csv"
        df = pd.read_csv(file_name)
        ens_rms.append(df.ens_rms.iloc[29])
    plt.plot(range(len(ens_rms)), ens_rms, label=f"{k}_swa")
        #plt.plot(range(len(df)), df.va_rms, label=f"{k}")
plt.legend()
plt.xlabel("Iterations")
plt.ylabel("RMS of 30 samples")
# Out:
# Text(0, 0.5, 'RMS of 30 samples')

# %%
K=[20, 60]
for k in K:
    ens_of_std = []
    ens_std = []
    for i in range(11, 71):
        file_name = f"SWAG_tune_K/128_0.005_3e-4_0.0001_70_0_{k}/val_results/val_eval_swag-{i}_residual_summary_30.csv"
        df = pd.read_csv(file_name)
        ens_of_std.append(df.ens_of_std.iloc[29])
        #ens_std.append(df.ens_residual_std.iloc[-1])

    plt.plot(range(len(ens_rms)), ens_of_std, label=f"{k}_of_std")
    #plt.plot(range(len(ens_rms)), ens_std, label=f"{k}_std", linestyle="--")
        #plt.plot(range(len(df)), df.va_rms, label=f"{k}")
plt.legend()
plt.xlabel("Iterations")
plt.ylabel("Residual Outer fence STD")
# Out:
# Text(0, 0.5, 'Residual Outer fence STD')

# %%
file_name = f"SWAG_tune_K/128_0.005_3e-4_0.0001_70_0_20/val_results/val_eval_swag-21_residual_summary_30.csv"
df = pd.read_csv(file_name)
plt.plot(np.arange(len(df))+1, df.ens_of_std, label=f"20_of_std")
#plt.plot(np.arange(len(df))+1, df.ens_rms, label=f"20_rms")
plt.legend()
plt.xlabel("Samples")
# Out:
# Text(0.5, 0, 'Samples')

# %% [markdown]
# ## Do calibration for various values of K and look at the distribution of calibration plots

# %% [markdown]
# # Larger SWAG learning rate - 100 samples

# %%
dir_name = f"SWAG_tune_K/128_0.005_3e-4_0.001_60_0_20"
df = pd.read_csv(f"{dir_name}/train_metrics.csv")
plt.plot(range(len(df)), df.swa_va_rms, label="swa")
plt.plot(range(len(df)), df.va_rms, label="not swa")
plt.legend()
plt.ylabel("Validation RMS")
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
for e in [50, 60]:
    file_name = f"SWAG_tune_K/128_0.005_3e-4_0.001_60_0_20/val_results/val_eval_swag-{e}_residual_summary_100.csv"
    df = pd.read_csv(file_name)
    plt.plot(np.arange(len(df))+1, df.ens_rms, label=f"20_rms")
    plt.legend()
    plt.xlabel("Samples")
    plt.ylabel("Ensemble RMS of N samples")
    plt.xticks(np.arange(0, 110, 10))
    plt.grid(True)

# %%
for e in [50, 60]:
    file_name = f"SWAG_tune_K/128_0.005_3e-4_0.001_60_0_20/val_results/val_eval_swag-{e}_residual_summary_100.csv"
    df = pd.read_csv(file_name)
    plt.plot(np.arange(len(df))+1, df.ens_of_std, label=f"{e-10} epochs")
    plt.legend()
    plt.xlabel("Samples")
    plt.ylabel("OF STD of N samples")
    plt.xticks(np.arange(0, 110, 10))
    plt.grid(True)

# %%
file_name = f"SWAG_tune_K/128_0.005_3e-4_0.001_60_0_20/val_results/val_eval_swag-50_residual_summary_100.csv"
df = pd.read_csv(file_name)

# %%
df.ens_of_std.values[22]
# Out:
# 0.04269195633589695

# %% [markdown]
# # Smaller learning rate - 100 samples @ swag epochs 50 and 60

# %%
for e in [50, 60]:
    file_name = f"SWAG_tune_K/128_0.005_3e-4_0.0001_70_0_20/val_results_100/val_eval_swag-{e}_residual_summary_100.csv"
    df = pd.read_csv(file_name)
    plt.plot(np.arange(len(df))+1, df.ens_of_std, label=f"{e-10} epochs")
    #plt.plot(np.arange(len(df))+1, df.ens_rms, label=f"20_rms")
    plt.legend()
    plt.xlabel("Samples")
    plt.ylabel("OF STD of N samples")

# %%
file_name = f"SWAG_tune_K/128_0.005_3e-4_0.0001_70_0_20/val_results_100/val_eval_swag-50_residual_summary_100.csv"
df = pd.read_csv(file_name)
plt.plot(np.arange(len(df))+1, df.ens_of_std, label="0.0001")

file_name = f"SWAG_tune_K/128_0.005_3e-4_0.001_60_0_20/val_results/val_eval_swag-50_residual_summary_100.csv"
df = pd.read_csv(file_name)
plt.plot(np.arange(len(df))+1, df.ens_of_std, label="0.001")

#plt.plot(np.arange(len(df))+1, df.ens_rms, label=f"20_rms")
plt.legend()
plt.xlabel("Samples")
plt.ylabel("OF STD of N samples")
# Out:
# Text(0, 0.5, 'OF STD of N samples')

# %%
# Above but zoomed in 
file_name = f"SWAG_tune_K/128_0.005_3e-4_0.0001_70_0_20/val_results_100/val_eval_swag-50_residual_summary_100.csv"
df = pd.read_csv(file_name)
plt.plot(np.arange(len(df))+1, df.ens_of_std, label="0.0001")

file_name = f"SWAG_tune_K/128_0.005_3e-4_0.001_60_0_20/val_results/val_eval_swag-50_residual_summary_100.csv"
df = pd.read_csv(file_name)
plt.plot(np.arange(len(df))+1, df.ens_of_std, label="0.001")

#plt.plot(np.arange(len(df))+1, df.ens_rms, label=f"20_rms")
plt.legend()
plt.xlabel("Samples")
plt.ylabel("OF STD of N samples")
plt.ylim([0.04, 0.055])
# Out:
# (0.04, 0.055)

# %%
file_name = f"SWAG_tune_K/128_0.005_3e-4_0.0001_70_0_20/val_results_100/val_eval_swag-50_residual_summary_100.csv"
df = pd.read_csv(file_name)
plt.plot(np.arange(len(df))+1, df.ens_rms, label="0.0001")

file_name = f"SWAG_tune_K/128_0.005_3e-4_0.001_60_0_20/val_results/val_eval_swag-50_residual_summary_100.csv"
df = pd.read_csv(file_name)
plt.plot(np.arange(len(df))+1, df.ens_rms, label="0.001")

#plt.plot(np.arange(len(df))+1, df.ens_rms, label=f"20_rms")
plt.legend()
plt.xlabel("Samples")
plt.ylabel("Ensemble RMS of N samples")
# Out:
# Text(0, 0.5, 'Ensemble RMS of N samples')

# %%
# Above but zoomed in 

file_name = f"SWAG_tune_K/128_0.005_3e-4_0.0001_70_0_20/val_results_100/val_eval_swag-50_residual_summary_100.csv"
df = pd.read_csv(file_name)
plt.plot(np.arange(len(df))+1, df.ens_rms, label="0.0001")

file_name = f"SWAG_tune_K/128_0.005_3e-4_0.001_60_0_20/val_results/val_eval_swag-50_residual_summary_100.csv"
df = pd.read_csv(file_name)
plt.plot(np.arange(len(df))+1, df.ens_rms, label="0.001")

#plt.plot(np.arange(len(df))+1, df.ens_rms, label=f"20_rms")
plt.legend()
plt.xlabel("Samples")
plt.ylabel("Ensemble RMS of N samples")
plt.ylim([0.082, 0.087])
# Out:
# (0.082, 0.087)
